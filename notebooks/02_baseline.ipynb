# %%
import pandas as pd
import sys
sys.path.append("..")

from features import extract_features, FEATURE_COLUMNS

df = pd.read_csv("../data/cleaned_malicious_phish.csv")   

df_features = extract_features(df.head())
df_features[FEATURE_COLUMNS]
# Out:
#    url_length  has_at  has_ip  subdomain_count
# 0          16   False   False                0
# 1          35   False   False                0
# 2          31   False   False                0
# 3          88   False   False                1
# 4         235   False   False                0
